# %%
import pandas as pd

# %%
titanic=pd.read_csv(r'C:\Users\38681\Documents\WeChat Files\wxid_cvbti3pwqawl22\FileStorage\File\2024-08\2022_Q1_OR_Utilization.csv')

# %%
titanic
# Out:
#       index  Encounter ID      Date  OR Suite      Service  CPT Code  \
# 0         0         10001  01/03/22         1     Podiatry     28110
# 1         1         10002  01/03/22         1     Podiatry     28055
# 2         2         10003  01/03/22         1     Podiatry     28297
# 3         3         10004  01/03/22         1     Podiatry     28296
# 4         4         10005  01/03/22         2  Orthopedics     27445
# ...     ...           ...       ...       ...          ...       ...
# 2167   2167         12168  03/31/22         7   Pediatrics     69421
# 2168   2168         12169  03/31/22         7   Pediatrics     69421
# 2169   2169         12170  03/31/22         8  Orthopedics     27445
# 2170   2170         12171  03/31/22         8  Orthopedics     27445
# 2171   2171         12172  03/31/22         8  Orthopedics     27130
#
#                                 CPT Description  Booked Time (min)  \
# 0      Partial ostectomy, fifth metatarsal head                 90
# ...

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.head(8)
# Out:
#    index  Encounter ID      Date  OR Suite        Service  CPT Code  \
# 0      0         10001  01/03/22         1       Podiatry     28110
# 1      1         10002  01/03/22         1       Podiatry     28055
# 2      2         10003  01/03/22         1       Podiatry     28297
# 3      3         10004  01/03/22         1       Podiatry     28296
# 4      4         10005  01/03/22         2    Orthopedics     27445
# 5      5         10006  01/03/22         2    Orthopedics     27445
# 6      6         10007  01/03/22         3  Ophthalmology     66982
# 7      7         10008  01/03/22         3  Ophthalmology     66982
#
#                              CPT Description  Booked Time (min)  \
# 0   Partial ostectomy, fifth metatarsal head                 90
# 1  Neurectomy, intrinsic musculature of foot                 60
# 2                       Lapidus bunionectomy                150
# 3         Bunionectomy with distal osteotomy                120
# ...

# %%
titanic.tail(5)
# Out:
#       index  Encounter ID      Date  OR Suite      Service  CPT Code  \
# 2167   2167         12168  03/31/22         7   Pediatrics     69421
# 2168   2168         12169  03/31/22         7   Pediatrics     69421
# 2169   2169         12170  03/31/22         8  Orthopedics     27445
# 2170   2170         12171  03/31/22         8  Orthopedics     27445
# 2171   2171         12172  03/31/22         8  Orthopedics     27130
#
#                           CPT Description  Booked Time (min)  \
# 2167      Myringotomy, general anesthesia                 60
# 2168      Myringotomy, general anesthesia                 60
# 2169  Arthroplasty, knee, hinge prothesis                120
# 2170  Arthroplasty, knee, hinge prothesis                120
# 2171                    Arthroplasty, hip                120
#
#             OR Schedule          Wheels In         Start Time  \
# 2167  03/31/22 10:45 AM  03/31/22 11:59 AM  03/31/22 12:11 PM
# ...

# %%
titanic.dtypes
# Out:
# index                 int64
# Encounter ID          int64
# Date                 object
# OR Suite              int64
# Service              object
# CPT Code              int64
# CPT Description      object
# Booked Time (min)     int64
# OR Schedule          object
# Wheels In            object
# Start Time           object
# End Time             object
# Wheels Out           object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2172 entries, 0 to 2171
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              2172 non-null   int64
#  1   Encounter ID       2172 non-null   int64
#  2   Date               2172 non-null   object
#  3   OR Suite           2172 non-null   int64
#  4   Service            2172 non-null   object
#  5   CPT Code           2172 non-null   int64
#  6   CPT Description    2172 non-null   object
#  7   Booked Time (min)  2172 non-null   int64
#  8   OR Schedule        2172 non-null   object
#  9   Wheels In          2172 non-null   object
#  10  Start Time         2172 non-null   object
#  11  End Time           2172 non-null   object
#  12  Wheels Out         2172 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 220.7+ KB

# %%
cpt=titanic['CPT Description']
cpt
# Out:
# 0        Partial ostectomy, fifth metatarsal head
# 1       Neurectomy, intrinsic musculature of foot
# 2                            Lapidus bunionectomy
# 3              Bunionectomy with distal osteotomy
# 4             Arthroplasty, knee, hinge prothesis
#                           ...
# 2167              Myringotomy, general anesthesia
# 2168              Myringotomy, general anesthesia
# 2169          Arthroplasty, knee, hinge prothesis
# 2170          Arthroplasty, knee, hinge prothesis
# 2171                            Arthroplasty, hip
# Name: CPT Description, Length: 2172, dtype: object

# %%
type(cpt)
# Out:
# pandas.core.series.Series

# %%
cpt.head(3)
# Out:
# 0     Partial ostectomy, fifth metatarsal head
# 1    Neurectomy, intrinsic musculature of foot
# 2                         Lapidus bunionectomy
# Name: CPT Description, dtype: object

# %%
cpt = titanic[['Service','CPT Description','OR Schedule']]
cpt
# Out:
#           Service                            CPT Description  \
# 0        Podiatry   Partial ostectomy, fifth metatarsal head
# 1        Podiatry  Neurectomy, intrinsic musculature of foot
# 2        Podiatry                       Lapidus bunionectomy
# 3        Podiatry         Bunionectomy with distal osteotomy
# 4     Orthopedics        Arthroplasty, knee, hinge prothesis
# ...           ...                                        ...
# 2167   Pediatrics            Myringotomy, general anesthesia
# 2168   Pediatrics            Myringotomy, general anesthesia
# 2169  Orthopedics        Arthroplasty, knee, hinge prothesis
# 2170  Orthopedics        Arthroplasty, knee, hinge prothesis
# 2171  Orthopedics                          Arthroplasty, hip
#
#             OR Schedule
# 0     01/03/22 07:00 AM
# 1     01/03/22 08:45 AM
# 2     01/03/22 10:00 AM
# 3     01/03/22 12:45 PM
# 4     01/03/22 07:00 AM
# ...                 ...
# 2167  03/31/22 10:45 AM
# 2168  03/31/22 12:00 PM
# ...

# %%
titanic
# Out:
#       index  Encounter ID      Date  OR Suite      Service  CPT Code  \
# 0         0         10001  01/03/22         1     Podiatry     28110
# 1         1         10002  01/03/22         1     Podiatry     28055
# 2         2         10003  01/03/22         1     Podiatry     28297
# 3         3         10004  01/03/22         1     Podiatry     28296
# 4         4         10005  01/03/22         2  Orthopedics     27445
# ...     ...           ...       ...       ...          ...       ...
# 2167   2167         12168  03/31/22         7   Pediatrics     69421
# 2168   2168         12169  03/31/22         7   Pediatrics     69421
# 2169   2169         12170  03/31/22         8  Orthopedics     27445
# 2170   2170         12171  03/31/22         8  Orthopedics     27445
# 2171   2171         12172  03/31/22         8  Orthopedics     27130
#
#                                 CPT Description  Booked Time (min)  \
# 0      Partial ostectomy, fifth metatarsal head                 90
# ...

# %%
bigOr = titanic[(titanic['OR Suite']>5) & (titanic['OR Suite']<8)]

bigOr
# Out:
#       index  Encounter ID      Date  OR Suite      Service  CPT Code  \
# 22       22         10023  01/03/22         6      Plastic     15773
# 23       23         10024  01/03/22         6      Plastic     15773
# 24       24         10025  01/03/22         6      Plastic     30400
# 25       25         10026  01/03/22         7     Vascular     28820
# 26       26         10027  01/03/22         7     Vascular     28820
# ...     ...           ...       ...       ...          ...       ...
# 2167   2167         12168  03/31/22         7   Pediatrics     69421
# 2168   2168         12169  03/31/22         7   Pediatrics     69421
# 2169   2169         12170  03/31/22         8  Orthopedics     27445
# 2170   2170         12171  03/31/22         8  Orthopedics     27445
# 2171   2171         12172  03/31/22         8  Orthopedics     27130
#
#                                     CPT Description  Booked Time (min)  \
# ...

# %%
pick = titanic[titanic['OR Suite'].isin ([6,7])]
pick
# Out:
#       index  Encounter ID      Date  OR Suite     Service  CPT Code  \
# 22       22         10023  01/03/22         6     Plastic     15773
# 23       23         10024  01/03/22         6     Plastic     15773
# 24       24         10025  01/03/22         6     Plastic     30400
# 25       25         10026  01/03/22         7    Vascular     28820
# 26       26         10027  01/03/22         7    Vascular     28820
# ...     ...           ...       ...       ...         ...       ...
# 2164   2164         12165  03/31/22         7  Pediatrics     69436
# 2165   2165         12166  03/31/22         7  Pediatrics     69436
# 2166   2166         12167  03/31/22         7  Pediatrics     69436
# 2167   2167         12168  03/31/22         7  Pediatrics     69421
# 2168   2168         12169  03/31/22         7  Pediatrics     69421
#
#                                     CPT Description  Booked Time (min)  \
# 22                                      Liposuction                180
# ...

# %%
sel = titanic[titanic['Wheels Out'].notna()][['Wheels In','Wheels Out']]
sel
# Out:
#               Wheels In         Wheels Out
# 0     01/03/22 07:05 AM  01/03/22 09:17 AM
# 1     01/03/22 09:48 AM  01/03/22 11:12 AM
# 2     01/03/22 11:50 AM  01/03/22 12:58 PM
# 3     01/03/22 01:29 PM  01/03/22 03:02 PM
# 4     01/03/22 07:15 AM  01/03/22 09:51 AM
# ...                 ...                ...
# 2167  03/31/22 11:59 AM  03/31/22 12:51 PM
# 2168  03/31/22 01:20 PM  03/31/22 02:28 PM
# 2169  03/31/22 07:06 AM  03/31/22 09:18 AM
# 2170  03/31/22 09:40 AM  03/31/22 12:01 PM
# 2171  03/31/22 12:40 PM  03/31/22 02:58 PM
#
# [2172 rows x 2 columns]

# %%
lim = titanic.iloc[5:10,2:5]
lim
# Out:
#        Date  OR Suite        Service
# 5  01/03/22         2    Orthopedics
# 6  01/03/22         3  Ophthalmology
# 7  01/03/22         3  Ophthalmology
# 8  01/03/22         3  Ophthalmology
# 9  01/03/22         3  Ophthalmology

# %%
lim['新列']=lim['OR Suite'] *2
lim
# Out:
#        Date  OR Suite        Service  新列
# 5  01/03/22         2    Orthopedics   4
# 6  01/03/22         3  Ophthalmology   6
# 7  01/03/22         3  Ophthalmology   6
# 8  01/03/22         3  Ophthalmology   6
# 9  01/03/22         3  Ophthalmology   6

# %%
lim_renamed = lim.rename(
    columns={
        'Date' : '日期',
        'OR Suite' : '手术室',
    }
    
)
lim_renamed
# Out:
#          日期  手术室        Service  新列
# 5  01/03/22    2    Orthopedics   4
# 6  01/03/22    3  Ophthalmology   6
# 7  01/03/22    3  Ophthalmology   6
# 8  01/03/22    3  Ophthalmology   6
# 9  01/03/22    3  Ophthalmology   6

# %%
lim[['OR Suite','新列']].mean()
# Out:
# OR Suite    2.8
# 新列          5.6
# dtype: float64

# %%
lim[['OR Suite','新列']].max()
# Out:
# OR Suite    3
# 新列          6
# dtype: int64

# %%
lim[['OR Suite','新列']].min()
# Out:
# OR Suite    2
# 新列          4
# dtype: int64

# %%
lim[['OR Suite','新列']].median()
# Out:
# OR Suite    3.0
# 新列          6.0
# dtype: float64

# %%
lim[['OR Suite','新列']].describe()
# Out:
#        OR Suite        新列
# count  5.000000  5.000000
# mean   2.800000  5.600000
# std    0.447214  0.894427
# min    2.000000  4.000000
# 25%    3.000000  6.000000
# 50%    3.000000  6.000000
# 75%    3.000000  6.000000
# max    3.000000  6.000000

# %%
titanic.head(10)
# Out:
#    index  Encounter ID      Date  OR Suite        Service  CPT Code  \
# 0      0         10001  01/03/22         1       Podiatry     28110
# 1      1         10002  01/03/22         1       Podiatry     28055
# 2      2         10003  01/03/22         1       Podiatry     28297
# 3      3         10004  01/03/22         1       Podiatry     28296
# 4      4         10005  01/03/22         2    Orthopedics     27445
# 5      5         10006  01/03/22         2    Orthopedics     27445
# 6      6         10007  01/03/22         3  Ophthalmology     66982
# 7      7         10008  01/03/22         3  Ophthalmology     66982
# 8      8         10009  01/03/22         3  Ophthalmology     66982
# 9      9         10010  01/03/22         3  Ophthalmology     66982
#
#                              CPT Description  Booked Time (min)  \
# 0   Partial ostectomy, fifth metatarsal head                 90
# 1  Neurectomy, intrinsic musculature of foot                 60
# ...

# %%
titanic[['OR Suite','Booked Time (min)']].groupby('OR Suite').mean()
# Out:
#           Booked Time (min)
# OR Suite
# 1                 89.512195
# 2                 78.452381
# 3                 48.314351
# 4                 85.298507
# 5                 66.713287
# 6                110.434783
# 7                 64.947917
# 8                113.709677
